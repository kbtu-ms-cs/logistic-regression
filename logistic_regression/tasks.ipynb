# %% [markdown]
# # Tasks

# %%
from jupyterquiz import display_quiz
import json
from base64 import b64encode
from IPython.display import display, Math

def get_spanned_encoded_q(q, q_name):
    byte_code = b64encode(bytes(json.dumps(q), 'utf8'))
    return f'<span style="display:none" id="{q_name}">{byte_code.decode()}</span>'

# %%
q_e_decimal_series = [{
    "question": "What’s the cost function of the logistic regression?",
    "type": "many_choice",
    "answers": [
        {
            "answer": "Sigmoid Function",
            "correct": False,
            "feedback": "Think a little bit more."
        },
        {
            "answer": "Logistic Function",
            "correct": False,
            "feedback": "Are you sure about that?"
        },
        {
            "answer": "Logistic and Sigmoid function",
            "correct": True,
            "feedback": "Yes! that is correct answer"
        },
        {
            "answer": "None of the above",
            "correct": False,
            "feedback": "No!"
        },
    ]
}]

# %%
display_quiz(q_e_decimal_series, max_width=780)
# Out:
# <div id="iKCAFTJjYzxJ" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="780"
#                style="border-radius: 10px; text-align: left"> <style>
# #iKCAFTJjYzxJ {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q_e_decimal_series = [{
    "question": "In logistic regression, the logistic loss function penalizes the model more when it is confident in predicting the correct outcome.",
    "type": "many_choice",
    "answers": [
        {
            "answer": "False",
            "correct": True,
            "feedback": "Yes! that is correct. In logistic regression, the logistic loss function penalizes the model more when it is confident in predicting the incorrect outcome, not the correct one. If the model is confident in predicting the correct outcome, the loss is relatively low. The loss increases significantly when the predicted probability diverges from the actual outcome, especially when the model is confident in an incorrect prediction."
        },
        {
            "answer": "True",
            "correct": False,
            "feedback": "Are you sure about that?"
        },
    ]
}]

# %%
display_quiz(q_e_decimal_series, max_width=780)
# Out:
# <div id="jLXcrvZCzsiA" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="780"
#                style="border-radius: 10px; text-align: left"> <style>
# #jLXcrvZCzsiA {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q_e_decimal_series = [{
    "question": "The logistic loss function for a single training example ""i"" is given by: J(θ)=−y^(i)log(h(θ)(x^(i))−(1−y^(i))log(1−h(θ)(x^(i)). If y^(i)=1, what happens to the loss if the predicted probability hθ(x(i)) approaches 1?" , 
    "type": "many_choice",
    "answers": [
        {
            "answer": "The loss increases significantly.",  
            "correct": True,
            "feedback": " Correct! Given function J(θ) above. And the scenario where y^(i)=1, let's analyze the effect on the loss if the predicted probability h(θ)(x^(i)) approaches 1: J(θ)=−1*log(h(θ)(x^(i)))−(1−1)*log(1−h(θ)(x(i))). The first term −1⋅log(h(θ)(x^(i))) will increase significantly as h(θ)(x^(i)) approaches 1 because log(1) is 0, and log(x) for 0<x<1 is negative. As h(θ)(x^(i)) gets closer to 1, the loss increases."
        },
        {
            "answer": "The loss decreases significantly.",
            "correct": False,
            "feedback": ""
        },
        {
            "answer": "The loss remains unchanged.",
            "correct": False,
            "feedback": ""
        },
        {
            "answer": "The loss becomes zero.",
            "correct": False,
            "feedback": ""
        },
    ]
}]

# %%
display_quiz(q_e_decimal_series, max_width=780)
# Out:
# <div id="cKqgxahYWavT" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="780"
#                style="border-radius: 10px; text-align: left"> <style>
# #cKqgxahYWavT {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q_e_decimal_series = [{
    "question": "What is the main objective during training in logistic regression?" , 
    "type": "many_choice",
    "answers": [
        {
            "answer": "Maximize the likelihood function.",    
            "correct": False,
            "feedback": ""
        },
        {
            "answer": "Minimize the sum of squared errors.",
            "correct": False,
            "feedback": ""
        },
        {
            "answer": "Minimize the logistic loss function.",
            "correct": True,
            "feedback": ""
        },
        {
            "answer": "Maximize the R-squared value.",
            "correct": False,
            "feedback": ""
        },
    ]
}]

# %%
display_quiz(q_e_decimal_series, max_width=780)
# Out:
# <div id="QSshJffHTIbt" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="780"
#                style="border-radius: 10px; text-align: left"> <style>
# #QSshJffHTIbt {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...

# %%
q_demo_seq = [{
    "question": "Suppose you have a logistic regression model with the following parameters: θ1= -2.5 θ2= 1.8 θ3=0.7; The logistic function is defined as h(θ)(x)=1/(1+e)^(−θTx), where x is a feature vector. For a specific data point with features x1=3.0 and x2=−1.5, calculate the predicted probability h(θ)(x) using the given logistic regression model parameters. Show your calculations and provide the final result rounded to three decimal places.",
    "type": "numeric",
    "answers": [
        {
            "type": "value",
            "value": 0.001,
            "correct": True,
            "feedback": "Correct! Explanation: θ0= −2.5; θ1= 1.8; θ2= 0.7; X1= 3.0; X2= −1.5. Substitute values into the function h(θ)(x) and calculate exponent. 1/(1+e^(2.5 + 1.8 * 3.0 + 0.7 * (−1.5))). You get h(θ)(x)= 1/966.865. and the final answer is 0.001034 rounded to three decimal is 0.001"
        },
        {
            "type": "default",
            "feedback": "Wrong answer!"
        }
    ]
}]

# %%
display_quiz(q_demo_seq)
# Out:
# <div id="cSIRDEVFKdsf" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-preserveresponses="false"
#                data-numquestions="1000000"
#                data-maxwidth="600"
#                style="border-radius: 10px; text-align: left"> <style>
# #cSIRDEVFKdsf {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
# ...
